# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pickle
from glob import glob

import numpy as np
import pandas as pd
from scipy.cluster.hierarchy import linkage
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import seaborn as sns

import settings as conf
from utils import is_number, chunker
import metadata

# %% [markdown]
# # Load PhenomeXcan vs Clinvar associations

# %%
phenomexcan_vs_clinvar_filename = os.path.join(conf.GENE_ASSOC_DIR, 'smultixcan_and_clinvar-z2.pkl.xz')
display(phenomexcan_vs_clinvar_filename)
# Out:
# '/mnt/phenomexcan_base/gene_assoc/smultixcan_and_clinvar-z2.pkl.xz'

# %%
phenomexcan_vs_clinvar = pd.read_pickle(phenomexcan_vs_clinvar_filename)

# %%
display(phenomexcan_vs_clinvar.shape)
display(phenomexcan_vs_clinvar.head())
# Out:
# (4091, 5106)
#                                                     Alzheimer's disease  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml               0.651161
# 2345-Ever_had_bowel_cancer_screening                           0.544953
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...             2.352883
# 100011_raw-Iron                                                2.905654
# 5221-Index_of_best_refractometry_result_right                  0.836999
#
#                                                     Alpha-2-macroglobulin deficiency  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                            0.247607
# 2345-Ever_had_bowel_cancer_screening                                        0.055165
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                          3.096874
# 100011_raw-Iron                                                             0.049563
# 5221-Index_of_best_refractometry_result_right                               0.071389
#
#                                                     Otitis media, susceptibility to  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                           3.820126
# 2345-Ever_had_bowel_cancer_screening                                       0.373364
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                         0.208791
# 100011_raw-Iron                                                           11.132239
# 5221-Index_of_best_refractometry_result_right                              0.229481
#
#                                                     p phenotype  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml       1.075217
# 2345-Ever_had_bowel_cancer_screening                   0.667099
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...     1.486795
# 100011_raw-Iron                                        0.978171
# 5221-Index_of_best_refractometry_result_right          0.340287
#
#                                                     Glucocorticoid deficiency with achalasia  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                    0.009677
# 2345-Ever_had_bowel_cancer_screening                                                1.731603
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                  0.166468
# 100011_raw-Iron                                                                     0.428900
# 5221-Index_of_best_refractometry_result_right                                       0.546314
#
#                                                     Keratosis palmoplantaris papulosa  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                             0.162067
# 2345-Ever_had_bowel_cancer_screening                                         5.829613
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                           0.268138
# 100011_raw-Iron                                                              0.395410
# 5221-Index_of_best_refractometry_result_right                                2.319034
#
#                                                     Charcot-Marie-Tooth disease, type 2N  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                1.670074
# 2345-Ever_had_bowel_cancer_screening                                            0.000311
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                              2.304044
# 100011_raw-Iron                                                                 0.199536
# 5221-Index_of_best_refractometry_result_right                                   4.984327
#
#                                                     Epileptic encephalopathy, early infantile, 29  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                         1.670074
# 2345-Ever_had_bowel_cancer_screening                                                     0.000311
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                       2.304044
# 100011_raw-Iron                                                                          0.199536
# 5221-Index_of_best_refractometry_result_right                                            4.984327
#
#                                                     Combined oxidative phosphorylation deficiency 8  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                           0.273777
# 2345-Ever_had_bowel_cancer_screening                                                       0.872317
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                         0.007125
# 100011_raw-Iron                                                                            0.638303
# 5221-Index_of_best_refractometry_result_right                                              0.177313
#
#                                                     Leukoencephalopathy, progressive, with ovarian failure  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                             0.273777
# 2345-Ever_had_bowel_cancer_screening                                                         0.872317
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                           0.007125
# 100011_raw-Iron                                                                              0.638303
# 5221-Index_of_best_refractometry_result_right                                                0.177313
#
#                                                     ...  \
# phenomexcan_traits                                  ...
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml    ...
# 2345-Ever_had_bowel_cancer_screening                ...
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...  ...
# 100011_raw-Iron                                     ...
# 5221-Index_of_best_refractometry_result_right       ...
#
#                                                     Retinitis pigmentosa 58  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                   0.292204
# 2345-Ever_had_bowel_cancer_screening                               0.871863
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                 0.020070
# 100011_raw-Iron                                                    0.000193
# 5221-Index_of_best_refractometry_result_right                      2.239274
#
#                                                     Myopia 21, autosomal dominant  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                         1.695379
# 2345-Ever_had_bowel_cancer_screening                                     0.772939
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                       0.137331
# 100011_raw-Iron                                                          0.327350
# 5221-Index_of_best_refractometry_result_right                            1.115672
#
#                                                     Paget disease of bone 6  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                   0.355525
# 2345-Ever_had_bowel_cancer_screening                               0.120311
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                 0.744516
# 100011_raw-Iron                                                    0.436058
# 5221-Index_of_best_refractometry_result_right                      0.141618
#
#                                                     Seborrhea-like dermatitis with psoriasiform elements  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                             1.101905
# 2345-Ever_had_bowel_cancer_screening                                                         0.015428
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                           0.810886
# 100011_raw-Iron                                                                              0.096868
# 5221-Index_of_best_refractometry_result_right                                                0.012610
#
#                                                     PEHO syndrome  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml         0.379410
# 2345-Ever_had_bowel_cancer_screening                     0.332303
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...       0.222463
# 100011_raw-Iron                                          0.173245
# 5221-Index_of_best_refractometry_result_right            1.253595
#
#                                                     Oocyte maturation defect 1  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                      1.747519
# 2345-Ever_had_bowel_cancer_screening                                  1.911665
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                    5.448538
# 100011_raw-Iron                                                       3.459105
# 5221-Index_of_best_refractometry_result_right                         0.031501
#
#                                                     OOCYTE MATURATION DEFECT 6  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                      0.272920
# 2345-Ever_had_bowel_cancer_screening                                  2.069227
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                    0.087805
# 100011_raw-Iron                                                       0.144557
# 5221-Index_of_best_refractometry_result_right                         0.244870
#
#                                                     OOCYTE MATURATION DEFECT 3  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                      0.006041
# 2345-Ever_had_bowel_cancer_screening                                  0.242165
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                    0.725028
# 100011_raw-Iron                                                       0.009105
# 5221-Index_of_best_refractometry_result_right                         0.001039
#
#                                                     Acromelic frontonasal dysostosis  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                            0.194577
# 2345-Ever_had_bowel_cancer_screening                                        0.392449
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                          0.155316
# 100011_raw-Iron                                                             0.015222
# 5221-Index_of_best_refractometry_result_right                               0.028283
#
#                                                     NEURODEVELOPMENTAL DISORDER WITH MOVEMENT ABNORMALITIES, ABNORMAL GAIT, AND AUTISTIC FEATURES
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                             0.194577
# 2345-Ever_had_bowel_cancer_screening                                                         0.392449
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                           0.155316
# 100011_raw-Iron                                                                              0.015222
# 5221-Index_of_best_refractometry_result_right                                                0.028283
#
# [5 rows x 5106 columns]

# %% [markdown]
# # Filter out traits with low z-scores

# %%
# plot z-score density
flat_values = phenomexcan_vs_clinvar.values.flatten()
flat_values = pd.Series(np.sqrt(flat_values))

plt.figure(figsize=(10, 8))
with sns.plotting_context(context='talk'):
    sns.distplot(flat_values)

# %%
flat_values.describe().apply(lambda x: '%.3f' % x)
# Out:
# count    20888646.000
# mean            0.873
# std             0.754
# min             0.000
# 25%             0.351
# 50%             0.730
# 75%             1.219
# max            40.000
# dtype: object

# %%
flat_values[flat_values > flat_values.quantile(0.9995)].shape
# Out:
# (10445,)

# %%
Z_THRESHOLD = 4.00
display(Z_THRESHOLD)
# Out:
# 4.0

# %%
phenomexcan_vs_clinvar_sqrt = np.sqrt(phenomexcan_vs_clinvar)
display(phenomexcan_vs_clinvar_sqrt.shape)
display(phenomexcan_vs_clinvar_sqrt.head())
# Out:
# (4091, 5106)
#                                                     Alzheimer's disease  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml               0.806946
# 2345-Ever_had_bowel_cancer_screening                           0.738209
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...             1.533911
# 100011_raw-Iron                                                1.704598
# 5221-Index_of_best_refractometry_result_right                  0.914876
#
#                                                     Alpha-2-macroglobulin deficiency  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                            0.497601
# 2345-Ever_had_bowel_cancer_screening                                        0.234871
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                          1.759794
# 100011_raw-Iron                                                             0.222627
# 5221-Index_of_best_refractometry_result_right                               0.267187
#
#                                                     Otitis media, susceptibility to  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                           1.954514
# 2345-Ever_had_bowel_cancer_screening                                       0.611035
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                         0.456937
# 100011_raw-Iron                                                            3.336501
# 5221-Index_of_best_refractometry_result_right                              0.479041
#
#                                                     p phenotype  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml       1.036927
# 2345-Ever_had_bowel_cancer_screening                   0.816761
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...     1.219342
# 100011_raw-Iron                                        0.989025
# 5221-Index_of_best_refractometry_result_right          0.583342
#
#                                                     Glucocorticoid deficiency with achalasia  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                    0.098373
# 2345-Ever_had_bowel_cancer_screening                                                1.315904
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                  0.408005
# 100011_raw-Iron                                                                     0.654905
# 5221-Index_of_best_refractometry_result_right                                       0.739131
#
#                                                     Keratosis palmoplantaris papulosa  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                             0.402575
# 2345-Ever_had_bowel_cancer_screening                                         2.414459
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                           0.517820
# 100011_raw-Iron                                                              0.628817
# 5221-Index_of_best_refractometry_result_right                                1.522838
#
#                                                     Charcot-Marie-Tooth disease, type 2N  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                1.292313
# 2345-Ever_had_bowel_cancer_screening                                            0.017647
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                              1.517908
# 100011_raw-Iron                                                                 0.446695
# 5221-Index_of_best_refractometry_result_right                                   2.232561
#
#                                                     Epileptic encephalopathy, early infantile, 29  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                         1.292313
# 2345-Ever_had_bowel_cancer_screening                                                     0.017647
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                       1.517908
# 100011_raw-Iron                                                                          0.446695
# 5221-Index_of_best_refractometry_result_right                                            2.232561
#
#                                                     Combined oxidative phosphorylation deficiency 8  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                           0.523237
# 2345-Ever_had_bowel_cancer_screening                                                       0.933979
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                         0.084412
# 100011_raw-Iron                                                                            0.798939
# 5221-Index_of_best_refractometry_result_right                                              0.421086
#
#                                                     Leukoencephalopathy, progressive, with ovarian failure  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                             0.523237
# 2345-Ever_had_bowel_cancer_screening                                                         0.933979
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                           0.084412
# 100011_raw-Iron                                                                              0.798939
# 5221-Index_of_best_refractometry_result_right                                                0.421086
#
#                                                     ...  \
# phenomexcan_traits                                  ...
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml    ...
# 2345-Ever_had_bowel_cancer_screening                ...
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...  ...
# 100011_raw-Iron                                     ...
# 5221-Index_of_best_refractometry_result_right       ...
#
#                                                     Retinitis pigmentosa 58  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                   0.540559
# 2345-Ever_had_bowel_cancer_screening                               0.933736
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                 0.141670
# 100011_raw-Iron                                                    0.013880
# 5221-Index_of_best_refractometry_result_right                      1.496420
#
#                                                     Myopia 21, autosomal dominant  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                         1.302067
# 2345-Ever_had_bowel_cancer_screening                                     0.879170
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                       0.370583
# 100011_raw-Iron                                                          0.572145
# 5221-Index_of_best_refractometry_result_right                            1.056254
#
#                                                     Paget disease of bone 6  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                   0.596259
# 2345-Ever_had_bowel_cancer_screening                               0.346859
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                 0.862854
# 100011_raw-Iron                                                    0.660347
# 5221-Index_of_best_refractometry_result_right                      0.376321
#
#                                                     Seborrhea-like dermatitis with psoriasiform elements  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                             1.049716
# 2345-Ever_had_bowel_cancer_screening                                                         0.124208
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                           0.900492
# 100011_raw-Iron                                                                              0.311236
# 5221-Index_of_best_refractometry_result_right                                                0.112292
#
#                                                     PEHO syndrome  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml         0.615962
# 2345-Ever_had_bowel_cancer_screening                     0.576457
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...       0.471659
# 100011_raw-Iron                                          0.416227
# 5221-Index_of_best_refractometry_result_right            1.119641
#
#                                                     Oocyte maturation defect 1  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                      1.321938
# 2345-Ever_had_bowel_cancer_screening                                  1.382630
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                    2.334210
# 100011_raw-Iron                                                       1.859867
# 5221-Index_of_best_refractometry_result_right                         0.177485
#
#                                                     OOCYTE MATURATION DEFECT 6  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                      0.522417
# 2345-Ever_had_bowel_cancer_screening                                  1.438481
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                    0.296318
# 100011_raw-Iron                                                       0.380206
# 5221-Index_of_best_refractometry_result_right                         0.494844
#
#                                                     OOCYTE MATURATION DEFECT 3  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                      0.077722
# 2345-Ever_had_bowel_cancer_screening                                  0.492102
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                    0.851486
# 100011_raw-Iron                                                       0.095420
# 5221-Index_of_best_refractometry_result_right                         0.032239
#
#                                                     Acromelic frontonasal dysostosis  \
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                            0.441108
# 2345-Ever_had_bowel_cancer_screening                                        0.626457
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                          0.394101
# 100011_raw-Iron                                                             0.123379
# 5221-Index_of_best_refractometry_result_right                               0.168177
#
#                                                     NEURODEVELOPMENTAL DISORDER WITH MOVEMENT ABNORMALITIES, ABNORMAL GAIT, AND AUTISTIC FEATURES
# phenomexcan_traits
# 20096_1-Size_of_red_wine_glass_drunk_small_125ml                                             0.441108
# 2345-Ever_had_bowel_cancer_screening                                                         0.626457
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                           0.394101
# 100011_raw-Iron                                                                              0.123379
# 5221-Index_of_best_refractometry_result_right                                                0.168177
#
# [5 rows x 5106 columns]

# %%
# filter by value in assoc_coef
display(f'Z_THRESHOLD: {Z_THRESHOLD}')

cols_to_remove = []
for col in phenomexcan_vs_clinvar_sqrt.columns:
    if phenomexcan_vs_clinvar_sqrt[col].max() < Z_THRESHOLD:
        cols_to_remove.append(col)

rows_to_remove = []
for idx, row in phenomexcan_vs_clinvar_sqrt.iterrows():
    if row.max() < Z_THRESHOLD:
        rows_to_remove.append(idx)

display((len(rows_to_remove), len(cols_to_remove)))
# Out:
# 'Z_THRESHOLD: 4.0'
# (2142, 695)

# %%
rows_to_remove[:5]
# Out:
# ['20096_1-Size_of_red_wine_glass_drunk_small_125ml',
#  '2345-Ever_had_bowel_cancer_screening',
#  '100011_raw-Iron',
#  '5221-Index_of_best_refractometry_result_right',
#  '20003_1141150624-Treatmentmedication_code_zomig_25mg_tablet']

# %%
phenomexcan_vs_clinvar_sqrt_selected = phenomexcan_vs_clinvar_sqrt.drop(columns=cols_to_remove)
phenomexcan_vs_clinvar_sqrt_selected = phenomexcan_vs_clinvar_sqrt_selected.drop(rows_to_remove)

# %%
display(phenomexcan_vs_clinvar_sqrt_selected.shape)
display(phenomexcan_vs_clinvar_sqrt_selected.head())
# Out:
# (1949, 4411)
#                                                     Alzheimer's disease  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...             1.533911
# 20024_1136-Job_code_deduced_Information_and_com...             1.167170
# 806-Job_involves_mainly_walking_or_standing                    1.064439
# 1060-Time_spent_outdoors_in_winter                             2.225252
# 20002_1373-Noncancer_illness_code_selfreported_...             0.984052
#
#                                                     Alpha-2-macroglobulin deficiency  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                          1.759794
# 20024_1136-Job_code_deduced_Information_and_com...                          1.781442
# 806-Job_involves_mainly_walking_or_standing                                 0.872511
# 1060-Time_spent_outdoors_in_winter                                          2.175974
# 20002_1373-Noncancer_illness_code_selfreported_...                          0.483619
#
#                                                     Otitis media, susceptibility to  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                         0.456937
# 20024_1136-Job_code_deduced_Information_and_com...                         0.200259
# 806-Job_involves_mainly_walking_or_standing                                0.491002
# 1060-Time_spent_outdoors_in_winter                                         1.074131
# 20002_1373-Noncancer_illness_code_selfreported_...                         0.292449
#
#                                                     p phenotype  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...     1.219342
# 20024_1136-Job_code_deduced_Information_and_com...     0.496048
# 806-Job_involves_mainly_walking_or_standing            0.744056
# 1060-Time_spent_outdoors_in_winter                     0.587395
# 20002_1373-Noncancer_illness_code_selfreported_...     1.596548
#
#                                                     Glucocorticoid deficiency with achalasia  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                  0.408005
# 20024_1136-Job_code_deduced_Information_and_com...                                  0.734752
# 806-Job_involves_mainly_walking_or_standing                                         0.085302
# 1060-Time_spent_outdoors_in_winter                                                  0.430628
# 20002_1373-Noncancer_illness_code_selfreported_...                                  0.483717
#
#                                                     Keratosis palmoplantaris papulosa  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                           0.517820
# 20024_1136-Job_code_deduced_Information_and_com...                           0.346126
# 806-Job_involves_mainly_walking_or_standing                                  0.238237
# 1060-Time_spent_outdoors_in_winter                                           1.347906
# 20002_1373-Noncancer_illness_code_selfreported_...                           0.605057
#
#                                                     Charcot-Marie-Tooth disease, type 2N  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                              1.517908
# 20024_1136-Job_code_deduced_Information_and_com...                              0.572916
# 806-Job_involves_mainly_walking_or_standing                                     1.529063
# 1060-Time_spent_outdoors_in_winter                                              0.305246
# 20002_1373-Noncancer_illness_code_selfreported_...                              0.529684
#
#                                                     Epileptic encephalopathy, early infantile, 29  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                       1.517908
# 20024_1136-Job_code_deduced_Information_and_com...                                       0.572916
# 806-Job_involves_mainly_walking_or_standing                                              1.529063
# 1060-Time_spent_outdoors_in_winter                                                       0.305246
# 20002_1373-Noncancer_illness_code_selfreported_...                                       0.529684
#
#                                                     Combined oxidative phosphorylation deficiency 8  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                         0.084412
# 20024_1136-Job_code_deduced_Information_and_com...                                         0.983466
# 806-Job_involves_mainly_walking_or_standing                                                0.755943
# 1060-Time_spent_outdoors_in_winter                                                         0.911463
# 20002_1373-Noncancer_illness_code_selfreported_...                                         1.684554
#
#                                                     Leukoencephalopathy, progressive, with ovarian failure  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                           0.084412
# 20024_1136-Job_code_deduced_Information_and_com...                                           0.983466
# 806-Job_involves_mainly_walking_or_standing                                                  0.755943
# 1060-Time_spent_outdoors_in_winter                                                           0.911463
# 20002_1373-Noncancer_illness_code_selfreported_...                                           1.684554
#
#                                                     ...  \
# phenomexcan_traits                                  ...
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...  ...
# 20024_1136-Job_code_deduced_Information_and_com...  ...
# 806-Job_involves_mainly_walking_or_standing         ...
# 1060-Time_spent_outdoors_in_winter                  ...
# 20002_1373-Noncancer_illness_code_selfreported_...  ...
#
#                                                     Corneal fragility keratoglobus, blue sclerae AND joint hypermobility  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                           0.788323
# 20024_1136-Job_code_deduced_Information_and_com...                                           1.374289
# 806-Job_involves_mainly_walking_or_standing                                                  0.249980
# 1060-Time_spent_outdoors_in_winter                                                           0.696363
# 20002_1373-Noncancer_illness_code_selfreported_...                                           1.357636
#
#                                                     Retinitis pigmentosa 58  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                 0.141670
# 20024_1136-Job_code_deduced_Information_and_com...                 1.551001
# 806-Job_involves_mainly_walking_or_standing                        0.834041
# 1060-Time_spent_outdoors_in_winter                                 0.682483
# 20002_1373-Noncancer_illness_code_selfreported_...                 0.458778
#
#                                                     Myopia 21, autosomal dominant  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                       0.370583
# 20024_1136-Job_code_deduced_Information_and_com...                       2.672544
# 806-Job_involves_mainly_walking_or_standing                              0.128594
# 1060-Time_spent_outdoors_in_winter                                       0.605986
# 20002_1373-Noncancer_illness_code_selfreported_...                       1.094217
#
#                                                     Paget disease of bone 6  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                 0.862854
# 20024_1136-Job_code_deduced_Information_and_com...                 1.521476
# 806-Job_involves_mainly_walking_or_standing                        2.069020
# 1060-Time_spent_outdoors_in_winter                                 2.478585
# 20002_1373-Noncancer_illness_code_selfreported_...                 0.406669
#
#                                                     Seborrhea-like dermatitis with psoriasiform elements  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                           0.900492
# 20024_1136-Job_code_deduced_Information_and_com...                                           0.382859
# 806-Job_involves_mainly_walking_or_standing                                                  1.276395
# 1060-Time_spent_outdoors_in_winter                                                           1.745194
# 20002_1373-Noncancer_illness_code_selfreported_...                                           0.306060
#
#                                                     PEHO syndrome  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...       0.471659
# 20024_1136-Job_code_deduced_Information_and_com...       0.742100
# 806-Job_involves_mainly_walking_or_standing              3.243742
# 1060-Time_spent_outdoors_in_winter                       3.214646
# 20002_1373-Noncancer_illness_code_selfreported_...       0.489312
#
#                                                     Oocyte maturation defect 1  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                    2.334210
# 20024_1136-Job_code_deduced_Information_and_com...                    1.269273
# 806-Job_involves_mainly_walking_or_standing                           1.631854
# 1060-Time_spent_outdoors_in_winter                                    0.743638
# 20002_1373-Noncancer_illness_code_selfreported_...                    0.186340
#
#                                                     OOCYTE MATURATION DEFECT 3  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                    0.851486
# 20024_1136-Job_code_deduced_Information_and_com...                    0.007474
# 806-Job_involves_mainly_walking_or_standing                           1.194704
# 1060-Time_spent_outdoors_in_winter                                    1.020932
# 20002_1373-Noncancer_illness_code_selfreported_...                    0.185514
#
#                                                     Acromelic frontonasal dysostosis  \
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                          0.394101
# 20024_1136-Job_code_deduced_Information_and_com...                          0.820057
# 806-Job_involves_mainly_walking_or_standing                                 1.938288
# 1060-Time_spent_outdoors_in_winter                                          0.778805
# 20002_1373-Noncancer_illness_code_selfreported_...                          0.524153
#
#                                                     NEURODEVELOPMENTAL DISORDER WITH MOVEMENT ABNORMALITIES, ABNORMAL GAIT, AND AUTISTIC FEATURES
# phenomexcan_traits
# N49-Diagnoses_main_ICD10_N49_Inflammatory_disor...                                           0.394101
# 20024_1136-Job_code_deduced_Information_and_com...                                           0.820057
# 806-Job_involves_mainly_walking_or_standing                                                  1.938288
# 1060-Time_spent_outdoors_in_winter                                                           0.778805
# 20002_1373-Noncancer_illness_code_selfreported_...                                           0.524153
#
# [5 rows x 4411 columns]

# %% [markdown]
# # Hierarchical clustering on rows and columns

# %%
z_rows = linkage(phenomexcan_vs_clinvar_sqrt_selected, 'average')
z_cols = linkage(phenomexcan_vs_clinvar_sqrt_selected.T, 'average')

# %%
t = np.array(phenomexcan_vs_clinvar_sqrt_selected.shape)
display(f'Data size: {t}')
fig_size = list(reversed(tuple((t / max(t)) * 200)))
display(fig_size)
# Out:
# 'Data size: [1949 4411]'
# [200.0, 88.36998413058264]

# %%
ax = sns.clustermap(
    data=phenomexcan_vs_clinvar_sqrt_selected,
    yticklabels=False, xticklabels=False,
    figsize=fig_size,
    row_linkage=z_rows, col_linkage=z_cols
)

ax.ax_row_dendrogram.set_visible(False)
ax.ax_col_dendrogram.set_visible(False)

# %%
clustermap_matrix = phenomexcan_vs_clinvar_sqrt_selected.iloc[ax.dendrogram_row.reordered_ind, ax.dendrogram_col.reordered_ind]
display(clustermap_matrix.shape)
# Out:
# (1949, 4411)

# %%
clustermap_matrix.head()
# Out:
#                                             Symphalangism, proximal, 1b  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                     4.731462
# 30050_raw-Mean_corpuscular_haemoglobin                         2.902513
# 30040_raw-Mean_corpuscular_volume                              2.058844
# 30270_raw-Mean_sphered_cell_volume                             1.449294
# 30260_raw-Mean_reticulocyte_volume                             2.053437
#
#                                             Brachydactyly, type a1, c  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                   4.731462
# 30050_raw-Mean_corpuscular_haemoglobin                       2.902513
# 30040_raw-Mean_corpuscular_volume                            2.058844
# 30270_raw-Mean_sphered_cell_volume                           1.449294
# 30260_raw-Mean_reticulocyte_volume                           2.053437
#
#                                             Acromesomelic dysplasia Hunter Thompson type  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                                      4.731462
# 30050_raw-Mean_corpuscular_haemoglobin                                          2.902513
# 30040_raw-Mean_corpuscular_volume                                               2.058844
# 30270_raw-Mean_sphered_cell_volume                                              1.449294
# 30260_raw-Mean_reticulocyte_volume                                              2.053437
#
#                                             Type C brachydactyly  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume              4.731462
# 30050_raw-Mean_corpuscular_haemoglobin                  2.902513
# 30040_raw-Mean_corpuscular_volume                       2.058844
# 30270_raw-Mean_sphered_cell_volume                      1.449294
# 30260_raw-Mean_reticulocyte_volume                      2.053437
#
#                                             Fibular hypoplasia and complex brachydactyly  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                                      4.731462
# 30050_raw-Mean_corpuscular_haemoglobin                                          2.902513
# 30040_raw-Mean_corpuscular_volume                                               2.058844
# 30270_raw-Mean_sphered_cell_volume                                              1.449294
# 30260_raw-Mean_reticulocyte_volume                                              2.053437
#
#                                             Multiple synostoses syndrome 2  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                        4.731462
# 30050_raw-Mean_corpuscular_haemoglobin                            2.902513
# 30040_raw-Mean_corpuscular_volume                                 2.058844
# 30270_raw-Mean_sphered_cell_volume                                1.449294
# 30260_raw-Mean_reticulocyte_volume                                2.053437
#
#                                             Osteoarthritis of hip  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume               4.731462
# 30050_raw-Mean_corpuscular_haemoglobin                   2.902513
# 30040_raw-Mean_corpuscular_volume                        2.058844
# 30270_raw-Mean_sphered_cell_volume                       1.449294
# 30260_raw-Mean_reticulocyte_volume                       2.053437
#
#                                             Grebe syndrome  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume        4.731462
# 30050_raw-Mean_corpuscular_haemoglobin            2.902513
# 30040_raw-Mean_corpuscular_volume                 2.058844
# 30270_raw-Mean_sphered_cell_volume                1.449294
# 30260_raw-Mean_reticulocyte_volume                2.053437
#
#                                             Cortical dysplasia, complex, with other brain malformations 6  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                                           3.900522
# 30050_raw-Mean_corpuscular_haemoglobin                                               4.133993
# 30040_raw-Mean_corpuscular_volume                                                    0.761882
# 30270_raw-Mean_sphered_cell_volume                                                   6.720109
# 30260_raw-Mean_reticulocyte_volume                                                  11.985074
#
#                                             Michelin-tire baby  ...  \
# phenomexcan_traits                                              ...
# 30100_raw-Mean_platelet_thrombocyte_volume            3.900522  ...
# 30050_raw-Mean_corpuscular_haemoglobin                4.133993  ...
# 30040_raw-Mean_corpuscular_volume                     0.761882  ...
# 30270_raw-Mean_sphered_cell_volume                    6.720109  ...
# 30260_raw-Mean_reticulocyte_volume                   11.985074  ...
#
#                                             Townes-Brocks syndrome 1  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                  1.406331
# 30050_raw-Mean_corpuscular_haemoglobin                      1.532716
# 30040_raw-Mean_corpuscular_volume                           0.449345
# 30270_raw-Mean_sphered_cell_volume                          0.529857
# 30260_raw-Mean_reticulocyte_volume                          0.024956
#
#                                             Parkinson disease 11  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume              0.878565
# 30050_raw-Mean_corpuscular_haemoglobin                  1.549973
# 30040_raw-Mean_corpuscular_volume                       1.955158
# 30270_raw-Mean_sphered_cell_volume                      1.723171
# 30260_raw-Mean_reticulocyte_volume                      1.568462
#
#                                             Snowflake vitreoretinal degeneration  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                              1.273427
# 30050_raw-Mean_corpuscular_haemoglobin                                  1.784803
# 30040_raw-Mean_corpuscular_volume                                       2.001667
# 30270_raw-Mean_sphered_cell_volume                                      1.751668
# 30260_raw-Mean_reticulocyte_volume                                      1.187347
#
#                                             Leber congenital amaurosis 16  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                       1.273427
# 30050_raw-Mean_corpuscular_haemoglobin                           1.784803
# 30040_raw-Mean_corpuscular_volume                                2.001667
# 30270_raw-Mean_sphered_cell_volume                               1.751668
# 30260_raw-Mean_reticulocyte_volume                               1.187347
#
#                                             Cerebellar ataxia, nonprogressive, with mental retardation  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                                           8.322121
# 30050_raw-Mean_corpuscular_haemoglobin                                               1.613504
# 30040_raw-Mean_corpuscular_volume                                                    1.681089
# 30270_raw-Mean_sphered_cell_volume                                                   1.087806
# 30260_raw-Mean_reticulocyte_volume                                                   2.218463
#
#                                             Pulmonary veno-occlusive disease  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                          3.159152
# 30050_raw-Mean_corpuscular_haemoglobin                              4.122258
# 30040_raw-Mean_corpuscular_volume                                   3.144189
# 30270_raw-Mean_sphered_cell_volume                                  3.543794
# 30260_raw-Mean_reticulocyte_volume                                  3.608027
#
#                                             Primary pulmonary hypertension  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                        3.159152
# 30050_raw-Mean_corpuscular_haemoglobin                            4.122258
# 30040_raw-Mean_corpuscular_volume                                 3.144189
# 30270_raw-Mean_sphered_cell_volume                                3.543794
# 30260_raw-Mean_reticulocyte_volume                                3.608027
#
#                                             Pilomatrixoma  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume       7.309667
# 30050_raw-Mean_corpuscular_haemoglobin           0.611920
# 30040_raw-Mean_corpuscular_volume                1.207961
# 30270_raw-Mean_sphered_cell_volume               1.754809
# 30260_raw-Mean_reticulocyte_volume               1.124968
#
#                                             Mental retardation, autosomal dominant 19  \
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                                   0.078364
# 30050_raw-Mean_corpuscular_haemoglobin                                       0.584763
# 30040_raw-Mean_corpuscular_volume                                            1.111495
# 30270_raw-Mean_sphered_cell_volume                                           1.626424
# 30260_raw-Mean_reticulocyte_volume                                           1.251059
#
#                                             EXUDATIVE VITREORETINOPATHY 7
# phenomexcan_traits
# 30100_raw-Mean_platelet_thrombocyte_volume                       0.078364
# 30050_raw-Mean_corpuscular_haemoglobin                           0.584763
# 30040_raw-Mean_corpuscular_volume                                1.111495
# 30270_raw-Mean_sphered_cell_volume                               1.626424
# 30260_raw-Mean_reticulocyte_volume                               1.251059
#
# [5 rows x 4411 columns]

# %% [markdown]
# # Save

# %%
# for internal usage
clustermap_matrix_filename = os.path.join(conf.RESULTS_DIR, 'phenomexcan_vs_clinvar-clustermap.pkl.xz')
display(clustermap_matrix_filename)
# Out:
# '/mnt/phenomexcan_base/results/phenomexcan_vs_clinvar-clustermap.pkl.xz'

# %%
clustermap_matrix.to_pickle(clustermap_matrix_filename)

# %%
# for publication (csv)
clustermap_matrix_filename = os.path.join(conf.RESULTS_DIR, 'phenomexcan_vs_clinvar-clustermap.tsv.gz')
display(clustermap_matrix_filename)
# Out:
# '/mnt/phenomexcan_base/results/phenomexcan_vs_clinvar-clustermap.tsv.gz'

# %%
clustermap_matrix.to_csv(clustermap_matrix_filename, sep='\t')
